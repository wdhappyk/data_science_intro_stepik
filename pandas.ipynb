# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
students_performance = pd.read_csv("StudentsPerformance.csv")

# %%
students_performance.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
students_performance.iloc[0:5, 0:3]
# Out:
#    gender race/ethnicity parental level of education
# 0  female        group B           bachelor's degree
# 1  female        group C                some college
# 2  female        group B             master's degree
# 3    male        group A          associate's degree
# 4    male        group C                some college

# %%
students_performance.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
students_performance_with_names = students_performance.iloc[[0,3,4,7,8]]
students_performance_with_names.index = ["Cersei", "Tywin", "Gregor", "Joffrey", "Ilyn Payne"]

# %%
students_performance_with_names
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# Cersei      female        group B           bachelor's degree      standard
# Tywin         male        group A          associate's degree  free/reduced
# Gregor        male        group C                some college      standard
# Joffrey       male        group B                some college  free/reduced
# Ilyn Payne    male        group D                 high school  free/reduced
#
#            test preparation course  math score  reading score  writing score
# Cersei                        none          72             72             74
# Tywin                         none          47             57             44
# Gregor                        none          76             78             75
# Joffrey                       none          40             43             39
# Ilyn Payne               completed          64             64             67

# %%
students_performance_with_names.loc[["Cersei", "Tywin", "Gregor"], ["gender", "race/ethnicity"]]
# Out:
#         gender race/ethnicity
# Cersei  female        group B
# Tywin     male        group A
# Gregor    male        group C

# %%
students_performance.loc[:7]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# ...

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.dtypes.value_counts()
# Out:
# object     5
# int64      5
# float64    2
# dtype: int64

# %%
res_of_q1 = students_performance.loc[students_performance.lunch == "free/reduced"]

# %%
len(res_of_q1) / len(students_performance)
# Out:
# 0.355

# %%
(students_performance.lunch == "free/reduced").mean()
# Out:
# 0.355

# %%
gs = students_performance.groupby("lunch")
gs.describe()
# Out:
#              math score                                                       \
#                   count       mean        std   min   25%   50%   75%    max
# lunch
# free/reduced      355.0  58.921127  15.159956   0.0  49.0  60.0  69.0  100.0
# standard          645.0  70.034109  13.653501  19.0  61.0  69.0  80.0  100.0
#
#              reading score             ...              writing score  \
#                      count       mean  ...   75%    max         count
# lunch                                  ...
# free/reduced         355.0  64.653521  ...  75.0  100.0         355.0
# standard             645.0  71.654264  ...  82.0  100.0         645.0
#
#
#                    mean        std   min   25%   50%   75%    max
# lunch
# free/reduced  63.022535  15.433823  10.0  53.0  64.0  74.0  100.0
# standard      70.823256  14.339487  22.0  62.0  72.0  81.0  100.0
#
# [2 rows x 24 columns]

# %%
students_performance.query("`writing score` > 74")
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
dota_hero = pd.read_csv('dota_hero_stats.csv')

# %%
dota_hero.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles
# 0                       ['Carry', 'Escape', 'Nuker']
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
dota_hero.groupby('legs').count()
# Out:
#       Unnamed: 0  attack_type  id  localized_name  name  primary_attr  roles
# legs
# 0             11           11  11              11    11            11     11
# 2             95           95  95              95    95            95     95
# 4              7            7   7               7     7             7      7
# 6              3            3   3               3     3             3      3
# 8              1            1   1               1     1             1      1

# %%
accountancy = pd.read_csv('accountancy.csv')

# %%
accountancy.head()
# Out:
#    Unnamed: 0 Executor Type  Salary
# 0           0     Pupa    D      63
# 1           1     Pupa    A     158
# 2           2     Pupa    D     194
# 3           3     Pupa    E     109
# 4           4    Loopa    E     184

# %%
accountancy.groupby(['Executor', 'Type']).mean().unstack()
# Out:
#          Unnamed: 0                                               Salary  \
# Type              A     B          C          D     E      F           A
# Executor
# Loopa          46.0  24.0  31.666667  31.857143  23.5  20.00   58.000000
# Pupa           16.0  41.0  23.000000  14.000000  19.8  25.75  160.833333
#
#
# Type               B           C           D      E       F
# Executor
# Loopa     145.166667  154.333333  137.714286  164.0  238.00
# Pupa       77.000000   74.500000  146.500000  131.2  136.25

# %%
dota_hero.groupby(["attack_type", "primary_attr"]).count()
# Out:
#                           Unnamed: 0  id  legs  localized_name  name  roles
# attack_type primary_attr
# Melee       agi                   19  19    19              19    19     19
#             int                    2   2     2               2     2      2
#             str                   35  35    35              35    35     35
# Ranged      agi                   18  18    18              18    18     18
#             int                   40  40    40              40    40     40
#             str                    3   3     3               3     3      3

# %%
algae = pd.read_csv("algae.csv")

# %%
algae.head()
# Out:
#                species       genus  group   sucrose    alanin   citrate  \
# 0    Fucus_vesiculosus       Fucus  brown  3.001472  3.711498  5.004262
# 1  Saccharina_japonica  Saccharina  brown  6.731070  1.255251  5.621499
# 2       Fucus_serratus       Fucus  brown  3.276870  0.346431  1.216767
# 3      Fucus_distichus       Fucus  brown  6.786996  6.641303  6.423606
# 4    Cladophora_fracta  Cladophora  green  3.861470  1.648450  6.940588
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886

# %%
v = algae.groupby("genus").aggregate({ "alanin": ["min", "mean", "max"] }).loc["Fucus"]

# %%
" ".join([str(round(i, 2)) for i in v.array])
# Out:
# '0.35 3.57 6.64'

# %%
algae.groupby("group").aggregate({ "sucrose": np.ptp, "citrate": "var", "genus": "count" })
# Out:
#         sucrose   citrate  genus
# group
# brown  5.189345  5.468942      6
# green  3.259662  3.950113      3
# red    0.000000       NaN      1

# %%
algae.plot("genus", "citrate", kind="scatter")
# Out:
# <AxesSubplot:xlabel='genus', ylabel='citrate'>

# %%
students_performance['math score'].hist()
# Out:
# <AxesSubplot:>

# %%
income = pd.read_csv("income.csv")

# %%
income.head()
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
sns.lineplot(data=income)
# Out:
# <AxesSubplot:>

# %%
income.plot()
# Out:
# <AxesSubplot:>

# %%
income.income.plot()
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(x=income.index, y=income.income)
# Out:
# <AxesSubplot:ylabel='income'>

# %%
income.plot(kind="line")
# Out:
# <AxesSubplot:>

# %%
plt.plot(income.index, income.income)

# %%
df = pd.read_table("dataset_209770_6.txt", sep=" ")
sns.scatterplot(x="x", y="y", data=df)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
genome_matrix = pd.read_csv("genome_matrix.csv", index_col=0)
genome_matrix.head()
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
g = sns.heatmap(genome_matrix, cmap="viridis")
g.xaxis.set_ticks_position("top")
g.xaxis.set_tick_params(rotation=90)

# %%
dota_hero.roles.agg(lambda x: str.count(x, ",") + 1).mode()
# Out:
# 0    4
# dtype: int64

# %%
iris = pd.read_csv("iris.csv", index_col=0)

# %%
iris.head()
# Out:
#    sepal length  sepal width  petal length  petal width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
sns.kdeplot(data=iris.iloc[:,0:4])
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.violinplot(y=iris["petal length"])
# Out:
# <AxesSubplot:ylabel='petal length'>

# %%
sns.pairplot(iris, hue="species")
